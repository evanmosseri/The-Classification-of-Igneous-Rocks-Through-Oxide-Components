# %%
""" TODO:
- implement k-fold cross validation
-         
"""
import numpy as np
import pandas as pd
import scipy as st
import csv
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
import rocksep_utils as utl

# from sklearn.ensemble import BaggingClassifier
from sklearn import cross_validation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.lda import LDA
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

dataURL = "peridotites_clean_complete.csv"

rock_types={'DUNITE' :1,'HARZBURGITE':2, 'LHERZOLITE':3, 'WEHRLITE':4}

pd_data = pd.read_csv(dataURL)
chemicals = pd_data.keys()[1:].tolist()
rock_names = np.unique(pd_data[pd_data.keys()[0]])

random_data = pd_data.values
np.random.shuffle(random_data)

raw_data = random_data[:,1:]
labels = random_data[:,0]


# print np.delete(random_data,[len(random_data[0])-1,len(random_data[0])-2],1)[0]
# print random_data[0]

def numbered_labels(labels,key):
    return [key[labels[i]] for i in range(len(labels))]
nlabels =  numbered_labels(labels,rock_types)

def nearest_neighbors(data,labels,n):
    train_data = data[0:int(len(raw_data)/2)]
    test_data = data[int(len(raw_data)/2):]
    train_labels = labels[0:int(len(labels)/2)]
    test_labels = labels[int(len(labels)/2):]

    neigh = KNeighborsClassifier(n_neighbors=n)
    neigh.fit(train_data, train_labels)
    y_pred = neigh.predict(test_data)
    pure_accuracy_rate = len([y_pred[x] for x in range(len(y_pred)) if y_pred[x] == test_labels[x]])/float(len(test_labels))
    report = classification_report(y_pred, test_labels, target_names=rock_names)
    cm = confusion_matrix(test_labels, y_pred)
    return pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm

def random_forest(data,labels,n):
    train_data = data[0:int(len(raw_data)/2)]
    test_data = data[int(len(raw_data)/2):]
    train_labels = labels[0:int(len(labels)/2)]
    test_labels = labels[int(len(labels)/2):]

    neigh = RandomForestClassifier(n_estimators=n)
    neigh.fit(train_data, train_labels)
    y_pred = neigh.predict(test_data)
    pure_accuracy_rate = len([y_pred[x] for x in range(len(y_pred)) if y_pred[x] == test_labels[x]])/float(len(test_labels))
    report = classification_report(y_pred, test_labels, target_names=rock_names)
    cm = confusion_matrix(test_labels, y_pred)
    return pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm
# pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm = nearest_neighbors(raw_data,nlabels,4)
# pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm = random_forest(raw_data,nlabels,4)
# print pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm
# print cm,report,pure_accuracy_rate



fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')


plot_vars = ["SIO2","AL2O3","MGO"]


x1,y1,z1 = [test_data[:,chemicals.index(x)] for x in plot_vars]
cmap = {1:"red",2:"green",3:"blue",4:"orange"}
hit_shapes = {True:"*",False:"o"}

hit_mat = [y_pred[i] == test_labels[i] for i in range(len(test_labels))]
hit_shapes_mat = [hit_shapes[i] for i in hit_mat]
rock_colors = [cmap[x] for x in test_labels]

for i in range(len(hit_shapes_mat)):
    ax.scatter(x1[i], y1[i], zs=z1[i], c=rock_colors[i], marker=hit_shapes_mat[i],s=50)

proxy_labels = [matplotlib.lines.Line2D([0],[0], linestyle="none", c='black', marker = 'o'), matplotlib.lines.Line2D([0],[0], linestyle="none", c='black', marker = '*')]
for i in rock_types.values():
    proxy_labels.append(matplotlib.lines.Line2D([0],[0], linestyle="none", c=cmap[i], marker = 'o'))
ax.legend(proxy_labels, ['Incorrectly Classified', 'Correctly Classified']+rock_types.keys(), numpoints = 1)
ax.set_xlabel(plot_vars[0])
ax.set_ylabel(plot_vars[1])
ax.set_zlabel(plot_vars[2])
 
ax.set_title("3 Dimensional Demonstration of Classifier Accuracy")
plt.show()

# %%
""" TODO:
- implement k-fold cross validation
-         
"""
import numpy as np
import pandas as pd
import scipy as st
import csv
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
import rocksep_utils as utl

# from sklearn.ensemble import BaggingClassifier
from sklearn import cross_validation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.lda import LDA
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier

dataURL = "peridotites_clean_complete.csv"

rock_types={'DUNITE' :1,'HARZBURGITE':2, 'LHERZOLITE':3, 'WEHRLITE':4}

pd_data = pd.read_csv(dataURL)
chemicals = pd_data.keys()[1:].tolist()
rock_names = np.unique(pd_data[pd_data.keys()[0]])

random_data = pd_data.values
np.random.shuffle(random_data)

raw_data = random_data[:,1:]
labels = random_data[:,0]


# print np.delete(random_data,[len(random_data[0])-1,len(random_data[0])-2],1)[0]
# print random_data[0]

def numbered_labels(labels,key):
    return [key[labels[i]] for i in range(len(labels))]
nlabels =  numbered_labels(labels,rock_types)

def nearest_neighbors(data,labels,n):
    train_data = data[0:int(len(raw_data)/2)]
    test_data = data[int(len(raw_data)/2):]
    train_labels = labels[0:int(len(labels)/2)]
    test_labels = labels[int(len(labels)/2):]

    neigh = KNeighborsClassifier(n_neighbors=n)
    neigh.fit(train_data, train_labels)
    y_pred = neigh.predict(test_data)
    pure_accuracy_rate = len([y_pred[x] for x in range(len(y_pred)) if y_pred[x] == test_labels[x]])/float(len(test_labels))
    report = classification_report(y_pred, test_labels, target_names=rock_names)
    cm = confusion_matrix(test_labels, y_pred)
    return pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm

def random_forest(data,labels,n):
    train_data = data[0:int(len(raw_data)/2)]
    test_data = data[int(len(raw_data)/2):]
    train_labels = labels[0:int(len(labels)/2)]
    test_labels = labels[int(len(labels)/2):]

    neigh = RandomForestClassifier(n_estimators=n)
    neigh.fit(train_data, train_labels)
    y_pred = neigh.predict(test_data)
    pure_accuracy_rate = len([y_pred[x] for x in range(len(y_pred)) if y_pred[x] == test_labels[x]])/float(len(test_labels))
    report = classification_report(y_pred, test_labels, target_names=rock_names)
    cm = confusion_matrix(test_labels, y_pred)
    return pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm
pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm = nearest_neighbors(raw_data,nlabels,4)
# pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm = random_forest(raw_data,nlabels,4)
# print pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm
# print cm,report,pure_accuracy_rate
print report

cmap = {1:"red",2:"green",3:"blue",4:"orange"}
plot_vars = ["SIO2","AL2O3","MGO"]

def plotAnalysis(test_data,test_labels,label_colors,cmap,plot_vars)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    x1,y1,z1 = [test_data[:,chemicals.index(x)] for x in plot_vars]
    hit_shapes = {True:"*",False:"o"}

    hit_mat = [y_pred[i] == test_labels[i] for i in range(len(test_labels))]
    hit_shapes_mat = [hit_shapes[i] for i in hit_mat]
    rock_colors = [cmap[x] for x in test_labels]

    for i in range(len(hit_shapes_mat)):
        ax.scatter(x1[i], y1[i], zs=z1[i], c=rock_colors[i], marker=hit_shapes_mat[i],s=50)

    proxy_labels = [matplotlib.lines.Line2D([0],[0], linestyle="none", c='black', marker = 'o'), matplotlib.lines.Line2D([0],[0], linestyle="none", c='black', marker = '*')]
    for i in rock_types.values():
        proxy_labels.append(matplotlib.lines.Line2D([0],[0], linestyle="none", c=cmap[i], marker = 'o'))
    ax.legend(proxy_labels, ['Incorrectly Classified', 'Correctly Classified']+rock_types.keys(), numpoints = 1)
    ax.set_xlabel(plot_vars[0])
    ax.set_ylabel(plot_vars[1])
    ax.set_zlabel(plot_vars[2])
     
    ax.set_title("3 Dimensional Demonstration of Classifier Accuracy")
    plt.show()
plotAnalysis(test_data,test_labels,label_colors,cmap,plot_vars)
# Out:
#   File "<ipython-input-27-6c57a80ae4d5>", line 80
#     def plotAnalysis(test_data,test_labels,label_colors,cmap,plot_vars)
#                                                                        ^
# SyntaxError: invalid syntax

# %%
""" TODO:
- implement k-fold cross validation
-         
"""
import numpy as np
import pandas as pd
import scipy as st
import csv
from mpl_toolkits.mplot3d import Axes3D
import matplotlib
import matplotlib.pyplot as plt
from rocksep_utils import *


dataURL = "peridotites_clean_complete.csv"

rock_types={'DUNITE' :1,'HARZBURGITE':2, 'LHERZOLITE':3, 'WEHRLITE':4}

pd_data = pd.read_csv(dataURL)
chemicals = pd_data.keys()[1:].tolist()
rock_names = np.unique(pd_data[pd_data.keys()[0]])

random_data = pd_data.values
np.random.shuffle(random_data)

raw_data = random_data[:,1:]
labels = random_data[:,0]
nlabels =  numbered_labels(labels,rock_types)

# print np.delete(random_data,[len(random_data[0])-1,len(random_data[0])-2],1)[0]
# print random_data[0]



cmap = {1:"red",2:"green",3:"blue",4:"orange"}
plot_vars = ["SIO2","AL2O3","MGO"]



pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm,analysis_type = random_forest(raw_data,nlabels,4)
print analysis_type, report
plotAnalysis(test_data,test_labels,cmap,plot_vars,analysis_type,"3 Dimensional Demonstration of Classifier Accuracy",pure_accuracy_rate)
pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm,analysis_type = nearest_neighbors(raw_data,nlabels,4)
print analysis_type, report
plotAnalysis(test_data,test_labels,cmap,plot_vars,analysis_type,"3 Dimensional Demonstration of Classifier Accuracy",pure_accuracy_rate)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-390103c4b81a> in <module>()
#      38
#      39
# ---> 40 pure_accuracy_rate,report,y_pred,test_labels,test_data,neigh,cm,analysis_type = random_forest(raw_data,nlabels,4)
#      41 print analysis_type, report
#      42 plotAnalysis(test_data,test_labels,cmap,plot_vars,analysis_type,"3 Dimensional Demonstration of Classifier Accuracy",pure_accuracy_rate)
#
# ValueError: need more than 7 values to unpack
